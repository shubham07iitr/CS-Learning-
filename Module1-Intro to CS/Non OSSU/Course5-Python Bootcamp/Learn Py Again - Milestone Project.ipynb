# %% [markdown]
# <h2> Displaying info

# %%
def display(row1, row2, row3):
    print(row1)
    print(row2)
    print(row3)

# %%
example_row = [1,2,3]

display(example_row,example_row,example_row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row1 = ['', '', '']
row2 = ['', '', '']
row3 =['', '', '']

display(row1, row2, row3)
# Out:
# ['', '', '']
# ['', '', '']
# ['', '', '']

# %%
row2[1] = 'X'

# %%
display(row1,row2,row3)
# Out:
# ['', '', '']
# ['', 'X', '']
# ['', '', '']

# %% [markdown]
# <h2> Accepting user input

# %%
input("Please enter a value")
# Out:
# Please enter a value 12
# '12'

# %%
result = int(input("Please enter a value"))
# Out:
# Please enter a value 2

# %%
type(result)
# Out:
# int

# %%
position_index = int(input("Chose a position index: "))
# Out:
# Chose a position index:  1

# %%
row1[position_index]
# Out:
# ''

# %% [markdown]
# <h2> validating user input

# %%
def user_choice():
    
    choice = "Wrong"
    while choice.isdigit() == False:
        choice = input("Please enter a number (0-10)")

        if choice.isdigit() == False:
            print("Sorry this is not a digit")
    return int(choice)

# %%
some_value = '100'

# %%
some_value.isdigit() #isdigit checks if a string can be casted into an integr
# Out:
# True

# %%
user_choice()
# Out:
# Please enter a number (0-10) asda
# Sorry this is not a digit
# Please enter a number (0-10) 2
# 2

# %%
##updated code for ensuring input is within acceptable range

def user_choice():
    
    #Variables
    
    choice = "Wrong"
    acceptable_range = range(0,10)
    within_range = False
    
    
    #Two conditions to chekc 
    while choice.isdigit() == False or within_range == False:
        choice = input("Please enter a number (0-10)")

        #Digit Check
        if choice.isdigit() == False:
            print("Sorry this is not a digit")
        #Range Check
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True

            else:
                print("Sorry you are out of acceptable range")
                within_range = False
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10) asda
# Sorry this is not a digit
# Please enter a number (0-10) 23232
# Sorry you are out of acceptable range
# Please enter a number (0-10) 1
# 1

# %% [markdown]
# <h2> Simple user interaction
