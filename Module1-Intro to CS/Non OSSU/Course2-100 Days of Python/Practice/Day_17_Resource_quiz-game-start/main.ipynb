# %% [markdown]
# <h3> For Production or Long-Term Projects: Use a .py file.
# Convert the .ipynb file to a .py file (via File > Download as > Python (.py) in Jupyter Notebook) and import the .py file.
# This is more efficient, portable, and maintainable.
# For Prototyping or Exploratory Work: Use a .ipynb file.
# If you're still experimenting and want to leverage Jupyter's features (e.g., inline plots, markdowns), importing directly from a notebook is fine. </h3>

# %%
import import_ipynb
from data import question_data

import import_ipynb
from question_model import Question
from quiz_brain import QuizBrain

# %%
question_list = []
for i in question_data:
    a = Question(i["text"], i["answer"])
    question_list.append(a)

print(question_list)
# Out:
# [<question_model.Question object at 0x104375160>, <question_model.Question object at 0x1048baf60>, <question_model.Question object at 0x1043d7e00>, <question_model.Question object at 0x104914980>, <question_model.Question object at 0x104914ad0>, <question_model.Question object at 0x104914b60>, <question_model.Question object at 0x104914b30>, <question_model.Question object at 0x104914bc0>, <question_model.Question object at 0x104914c50>, <question_model.Question object at 0x104914c80>, <question_model.Question object at 0x104914cb0>, <question_model.Question object at 0x104914ce0>]

# %%
quiz = QuizBrain(question_list) ## passing the question list we created above as an argument here

# %%
while quiz.still_has_questions():
    quiz.next_question()

print("Completed quiz")
print(f"Your final score was {quiz.score}/{quiz.question_number}")
# Out:
# Q.1 A slug's blood is green. (True/False) true
# You got it
# The correct answer is True
# your score is 1/1
# Q.2 The loudest animal is the African Elephant. (True/False) true
# Thats wrong
# The correct answer is False
# your score is 1/2
# Q.3 Approximately one quarter of human bones are in the feet. (True/False) tru
# Thats wrong
# The correct answer is True
# your score is 1/3
# Q.4 The total surface area of a human lungs is the size of a football pitch. (True/False) true
# You got it
# The correct answer is True
# your score is 2/4
# Q.5 In West Virginia, USA, if you accidentally hit an animal with your car, you are free to take it home to eat. (True/False) true
# You got it
# The correct answer is True
# your score is 3/5
# Q.6 In London, UK, if you happen to die in the House of Parliament, you are entitled to a state funeral. (True/False) true
# Thats wrong
# The correct answer is False
# your score is 3/6
# ...
