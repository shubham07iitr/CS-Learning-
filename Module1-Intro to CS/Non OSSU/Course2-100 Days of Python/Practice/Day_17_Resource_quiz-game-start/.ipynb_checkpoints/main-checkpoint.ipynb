# %% [markdown]
# <h3> For Production or Long-Term Projects: Use a .py file.
# Convert the .ipynb file to a .py file (via File > Download as > Python (.py) in Jupyter Notebook) and import the .py file.
# This is more efficient, portable, and maintainable.
# For Prototyping or Exploratory Work: Use a .ipynb file.
# If you're still experimenting and want to leverage Jupyter's features (e.g., inline plots, markdowns), importing directly from a notebook is fine. </h3>

# %%
import import_ipynb
from data import question_data

import import_ipynb
from question_model import Question
from quiz_brain import QuizBrain

# %%
question_list = []
for i in question_data:
    a = Question(i["text"], i["answer"])
    question_list.append(a)

print(question_list)
# Out:
# [<question_model.Question object at 0x10688b500>, <question_model.Question object at 0x106a8d070>, <question_model.Question object at 0x106a8cd10>, <question_model.Question object at 0x106a8dca0>, <question_model.Question object at 0x106a8c860>, <question_model.Question object at 0x106a8c080>, <question_model.Question object at 0x106a8c8c0>, <question_model.Question object at 0x106a8c680>, <question_model.Question object at 0x106a8c440>, <question_model.Question object at 0x106a8cfb0>, <question_model.Question object at 0x106a8cec0>, <question_model.Question object at 0x106a8daf0>]

# %%
quiz = QuizBrain(question_list) ## passing the question list we created above as an argument here

# %%
quiz.next_question()
# Out:
# Q.0 A slug's blood is green. (True/False) True
