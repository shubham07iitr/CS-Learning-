# %% [markdown]
# <h3> Tkinter module history</h3>
#
# - Previously to interact with computer you needed cmd interface
# - Mac Lisa was the first type of computer which used GUI interface
# - It is alleged that MS stole the Apple idea of GUI but MS alleges back that Apple itself stole the idea from Xerox Parc
# - tkinter label class has been writted in form of kwargs, hence we dont see the arguments appear when we do shift + tab

# %%
import tkinter

window = tkinter.Tk() ## this will create an object of Tk class from within tkinter module which immediately gets exited
window.title("My first GUI program")
window.minsize(width = 500, height = 300) ##defining the size of hte window


##Label
my_label = tkinter.Label(text = "I am a label", font = ("Arial", 24, "bold")) ##crateing a label which will be displayed on the windo
my_label.pack(side = "bottom") ##need to use this to display on the window

window.mainloop() ## this will keep the window object running and will listen for user

# %%
## we can define default values of any functions 

def add_sum(a =1, b =2, c =3):
    return a + b + c


print(add_sum(b =5)) ##we dont have to define the params, and it will automatically pick up the default values
# Out:
# 9

# %% [markdown]
# <h3> *Args or Unlimited positional arguments </h3>
#
# - Functions that can take any number of arguments
# - *args is just a naming convention we can use *num or anything just * is important
# - Args will be taken as a tuple param, and all new elements passed in will be part of a tuple

# %%
## for e.g. an add function which we want to be fleble and accept any number of arguments and add

def add_any(*args):
    return sum(args)

add_any(2,3,4,2,32,4)


def add_any_loop(*args): ##another way of implementing the sum function
    counter = 0
    for i in args:
        counter += i
    return counter


add_any_loop(2,3,4,2,32,4)
# Out:
# 47

# %% [markdown]
# <h3> *kwargs or many keyword arguments </h3>
#
# - Functions that can take any number of keyword arguments
# - *kwargs is just a naming convention we can use *num or anything just * is important
# - Args will be taken as a dictionary param, and all new elements passed in will be part of a dictionary
# - Where key will be keyword and value will be vaule of the kw argument

# %%
def calculate(**kwargs):
    print(type(kwargs))

calculate(add = 3, multiple = 5) ## as you can see dictionary type gets printed here
# Out:
# <class 'dict'>

# %%
def calculate(n, **kwargs):
    print(type(kwargs))
    n += kwargs["add"] ##this is not a good example because here is also you wil need to know which kwargs or arguments will be passed
    n *= kwargs["add"]
    print(n
calculate(2, add = 3, multiple = 5)
# Out:
# <class 'dict'>
# 15

# %%
##Lets create a class with many kw arguments

class Car:
    def __init__(self, **kw): 
        self.make = kw.get("make")  ##now we can define or create an object and we can define the make and model of the car or can avoid it
        self.model = kw.get("model")


my_car = Car() ##if we are not passing the make and model it would still initialise because we used .get which has a fallback None option

#If we had used kw["make"] it would have thrown an error if we had not used make or model to define the object

# %%
## Going back to tkinter modules

## can update the property of a component we have created

import tkinter

window = tkinter.Tk() ## this will create an object of Tk class from within tkinter module which immediately gets exited
window.title("My first GUI program")
window.minsize(width = 500, height = 300) ##defining the size of hte window


##Label
my_label = tkinter.Label(text = "I am a label", font = ("Arial", 24, "bold")) ##crateing a label which will be displayed on the windo
my_label.pack() ##need to use this to display on the window



my_label["text"] = "New text" ##can use the dictionary method
my_label["text"] = "New New text" ##or can usse the config method




## Lets define another component input

input = tkinter.Entry(width = 10)
input.pack()



##a new funciton which will detect the click of the button and do something

def button_clicked():
    print("I got clicked")
    my_label["text"] = "Button got clicked" ##this will update the my_label variable 
    my_label["text"] = input.get()





##lets create a button object

button  = tkinter.Button(text = "click me", command = button_clicked) ## here commant = button_clicked is invoking the fn when the button will be clicked
button.pack()






window.mainloop() ## this will keep the window object running and will listen for user

# %% [markdown]
# <h3> Radiobuttons, scales, checkbuttons</h3>

# %%
from tkinter import *

#Creating a new window and configurations
window = Tk()
window.title("Widget Examples")
window.minsize(width=500, height=500)

#Labels
label = Label(text="This is old text")
label.config(text="This is new text")
label.pack()

#Buttons
def action():
    print("Do something")

#calls action() when pressed
button = Button(text="Click Me", command=action)
button.pack()

#Entries
entry = Entry(width=30)
#Add some text to begin with
entry.insert(END, string="Some text to begin with.")
#Gets text in entry
print(entry.get())
entry.pack()

#Text
text = Text(height=5, width=30)
#Puts cursor in textbox.
text.focus()
#Adds some text to begin with.
text.insert(END, "Example of multi-line text entry.")
#Get's current value in textbox at line 1, character 0
print(text.get("1.0", END))
text.pack()

#Spinbox
def spinbox_used():
    #gets the current value in spinbox.
    print(spinbox.get())
spinbox = Spinbox(from_=0, to=10, width=5, command=spinbox_used)
spinbox.pack()

#Scale
#Called with current scale value.
def scale_used(value):
    print(value)
scale = Scale(from_=0, to=100, command=scale_used)
scale.pack()

#Checkbutton
def checkbutton_used():
    #Prints 1 if On button checked, otherwise 0.
    print(checked_state.get())
#variable to hold on to checked state, 0 is off, 1 is on.
checked_state = IntVar()
checkbutton = Checkbutton(text="Is On?", variable=checked_state, command=checkbutton_used)
checked_state.get()
checkbutton.pack()

#Radiobutton
def radio_used():
    print(radio_state.get())
#Variable to hold on to which radio button value is checked.
radio_state = IntVar()
radiobutton1 = Radiobutton(text="Option1", value=1, variable=radio_state, command=radio_used)
radiobutton2 = Radiobutton(text="Option2", value=2, variable=radio_state, command=radio_used)
radiobutton1.pack()
radiobutton2.pack()


#Listbox
def listbox_used(event):
    # Gets current selection from listbox
    print(listbox.get(listbox.curselection()))

listbox = Listbox(height=4)
fruits = ["Apple", "Pear", "Orange", "Banana"]
for item in fruits:
    listbox.insert(fruits.index(item), item)
listbox.bind("<<ListboxSelect>>", listbox_used)
listbox.pack()
window.mainloop()
# Out:
# Some text to begin with.
# Example of multi-line text entry.

# %% [markdown]
# <h3> Pack, Place, Grid </h3>
#
# - Problem with pack is it is very difficult to specify the exact position where we want widgets to appear
# - Place is all about precise positioning
# - Grid divides your window in defined grids and you can specify which grid you want your

# %%
## Going back to tkinter modules using the pack method (whih automatically determines optimal position for widget to go )

## can update the property of a component we have created

import tkinter

window = tkinter.Tk() ## this will create an object of Tk class from within tkinter module which immediately gets exited
window.title("My first GUI program")
window.minsize(width = 500, height = 300) ##defining the size of hte window


##Label
my_label = tkinter.Label(text = "I am a label", font = ("Arial", 24, "bold")) ##crateing a label which will be displayed on the windo
my_label["text"] = "New New text" ##or can usse the config method
my_label.pack() ##need to use this to display on the window

##a new funciton which will detect the click of the button and do something

def button_clicked():
    print("I got clicked")
    my_label["text"] = "Button got clicked" ##this will update the my_label variable 
    my_label["text"] = input.get()
##lets create a button object
button  = tkinter.Button(text = "click me", command = button_clicked) ## here commant = button_clicked is invoking the fn when the button will be clicked
button.pack()


## Lets define another component input
input = tkinter.Entry(width = 10)
input.pack()

window.mainloop() ## this will keep the window object running and will listen for user

# %%
## Going back to tkinter modules using PLACE method where we have to specify the exact position (x=0, y=0 is the top left)

## can update the property of a component we have created

import tkinter

window = tkinter.Tk() ## this will create an object of Tk class from within tkinter module which immediately gets exited
window.title("My first GUI program")
window.minsize(width = 500, height = 300) ##defining the size of hte window


##Label
my_label = tkinter.Label(text = "I am a label", font = ("Arial", 24, "bold")) ##crateing a label which will be displayed on the windo
my_label["text"] = "New New text" ##or can usse the config method
my_label.place(x = 100, y = 100) ##need to use this to display on the window

##a new funciton which will detect the click of the button and do something

def button_clicked():
    print("I got clicked")
    my_label["text"] = "Button got clicked" ##this will update the my_label variable 
    my_label["text"] = input.get()
##lets create a button object
button  = tkinter.Button(text = "click me", command = button_clicked) ## here commant = button_clicked is invoking the fn when the button will be clicked
button.place(x = 200, y = 200)


## Lets define another component input
input = tkinter.Entry(width = 10)
input.place(x = 290, y = 290)

window.mainloop() ## this will keep the window object running and will listen for user

# %%
## Going back to tkinter modules using GRID method where we have to specify the exact position of the grid (column=0, row=0 is the top left)

## can update the property of a component we have created

import tkinter

window = tkinter.Tk() ## this will create an object of Tk class from within tkinter module which immediately gets exited
window.title("My first GUI program")
window.minsize(width = 500, height = 300) ##defining the size of hte window
window.config(padx = 20, pady = 20) ## will allow padding on x and y axis and grid will happen after the padding 

##Label
my_label = tkinter.Label(text = "I am a label", font = ("Arial", 24, "bold")) ##crateing a label which will be displayed on the windo
my_label["text"] = "New New text" ##or can usse the config method
my_label.grid(column = 0, row = 0) ##need to use this to display on the window, this will always be top left, whatever nunber we put it inside
my_label.config(padx = 0, pady = 0) ## can specify padding for a specific widget


##a new funciton which will detect the click of the button and do something

def button_clicked():
    print("I got clicked")
    my_label["text"] = "Button got clicked" ##this will update the my_label variable 
    my_label["text"] = input.get()
##lets create a button object
button  = tkinter.Button(text = "click me", command = button_clicked) ## here commant = button_clicked is invoking the fn when the button will be clicked
button.grid(column = 0, row = 10) ## will place the object underneath the label
button.config(padx = 100, pady = 100)
##button.place(x = 200, y = 200)


## Lets define another component input
input = tkinter.Entry(width = 10)
##input.place(x = 290, y = 290)
input.grid(column = 0, row = 20) ## will place the object underneath the button


window.mainloop() ## this will keep the window object running and will listen for user

# %% [markdown]
# <h3> Miles to Km Converter </h3>
#
# - Create a windows object perhaps 50 by 100 minisize and title as "Miles to Km converter"
# - Create an empty label at 0,0
# - Create an input/enntry method at 1,0
# - Create a label 'Miles' at 2,0
# - Create a label 'is equal to' at 0,1
# - Create a dynamic label with defaul value 0 at 1,1 which will get updated based on click from "Calculate"
# - Create a label "km" at 2,1
# - Create a button called "Calculate" at (1,2)
# - Create a function for Calculate to update value for 0 label

# %%
import tkinter

window = tkinter.Tk() ## this will create an object of Tk class from within tkinter module which immediately gets exited
window.title("Miles to Km Converter")
window.minsize(width = 300, height = 100) ##defining the size of hte window

##Labels
blank_label = tkinter.Label(text = "") 
blank_label.grid(column = 0, row = 0)

miles_label = tkinter.Label(text = "Miles") 
miles_label.grid(column = 2, row = 0)

equal_label  = tkinter.Label(text = "is equal to") 
equal_label.grid(column = 0, row = 1)

zero_label  = tkinter.Label(text = "0") 
zero_label.grid(column = 1, row = 1)

km_label  = tkinter.Label(text = "Kms") 
km_label.grid(column = 2, row = 1)

##Input box
input_entry = tkinter.Entry(width = 10)
input_entry.grid(column = 1, row = 0) ## will place the object underneath the button



##Button widget
def button_clicked():
    kms = float(input_entry.get()) * 1.609
    zero_label.config(text = kms) 

##lets create a button object
button  = tkinter.Button(text = "Calculate", command = button_clicked) ## here commant = button_clicked is invoking the fn when the button will be clicked
button.grid(column = 1, row = 2) ## will place the object underneath the label


window.mainloop() ## this will keep the window object running and will listen for user
