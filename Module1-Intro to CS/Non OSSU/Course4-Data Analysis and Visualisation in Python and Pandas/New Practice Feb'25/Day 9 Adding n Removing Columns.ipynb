# %%
import pandas as pd
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
nf = pd.read_csv("data/netflix_titles.csv", sep = "|", index_col = 0)
btc =  pd.read_csv("data/coin_Bitcoin.csv")
countries = pd.read_csv("data/world-happiness-report-2021.csv")
countries.set_index("Country name", inplace=  True)

# %% [markdown]
# <h3> Dropping a columns</h3>

# %%
btc.head(1)
# Out:
#    SNo     Name Symbol                 Date        High    Low     Open  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.0  134.444
#
#         Close  Volume     Marketcap
# 0  144.539993     0.0  1.603769e+09

# %%
btc.drop(labels = ["SNo", "Symbol", "Name"], axis = 1).head(1) ## axis = 1 specifies a column
# Out:
#                   Date        High    Low     Open       Close  Volume  \
# 0  2013-04-29 23:59:59  147.488007  134.0  134.444  144.539993     0.0
#
#       Marketcap
# 0  1.603769e+09

# %%
##Another way of doing this faster would be columns param
btc.drop(columns = ["SNo", "Symbol", "Name"]).head(1)
# Out:
#                   Date        High    Low     Open       Close  Volume  \
# 0  2013-04-29 23:59:59  147.488007  134.0  134.444  144.539993     0.0
#
#       Marketcap
# 0  1.603769e+09

# %% [markdown]
# <h3> Dropping  rows </h3>

# %%
countries.drop(labels = ["Denmark", "Finland"], axis = 0).head(5) ## Dropping denmark index , by default axis = 0 and deletes rows
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
# Norway           Western Europe         7.392                           0.035
# Sweden           Western Europe         7.363                           0.036
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
# Norway               7.462         7.323                 11.053
# Sweden               7.433         7.293                 10.867
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
btc.sort_index(ascending= False, inplace = True)
btc.drop(2990) ##will automatically pick the index label 2990 and delete it
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2985  2986  Bitcoin    BTC  2021-07-01 23:59:59  35035.982712  32883.781226
# ...    ...      ...    ...                  ...           ...           ...
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
#
# ...

# %%
## if we dont know the label names
countries.drop(countries.index[0:3]).head(1)
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Iceland          Western Europe         7.554                           0.059
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Iceland               7.67         7.438                 10.878
#
#               Social support  Healthy life expectancy  \
# Country name
# Iceland                0.983                     73.0
#
#               Freedom to make life choices  Generosity  \
# Country name
# Iceland                              0.955        0.16
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Iceland                           0.673                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Iceland                                  1.482                         1.172
#
#               Explained by: Healthy life expectancy  \
# ...

# %% [markdown]
# <h3> Adding a new column </h3>

# %%
titanic["species"] = "human" ## will add a new column with human value at teh end
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#       age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# ...

# %%
houses.insert(0, "County", "King County") ## will insert a new column called County at index 0 and assign King County to all values

# %%
houses.head(1)
# Out:
#         County          id             date     price  bedrooms  bathrooms  \
# 0  King County  7129300520  20141013T000000  221900.0         3        1.0
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
#
# [1 rows x 22 columns]

# %%
houses.insert(4, "num_beds", houses["bedrooms"]) ## creating a new columna and assigning a new series to it
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zn/6npf5pd5277gbjjtr2b6gy400000gn/T/ipykernel_30600/23811402.py in ?()
# ----> 1 houses.insert(4, "num_beds", houses["bedrooms"]) ## creating a new columna and assigning a new series to it
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
# ...

# %%
houses.head(1)
# Out:
#         County          id             date  num_beds     price  bedrooms  \
# 0  King County  7129300520  20141013T000000         3  221900.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  grade  sqft_above  \
# 0        1.0         1180      5650     1.0  ...      7        1180
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
#
# [1 rows x 23 columns]

# %% [markdown]
# <h3> Dynamic Columns </h3>

# %%
titanic.drop(columns = "species").head(1)
# Out:
#    pclass  survived                           name     sex age  sibsp  parch  \
# 0       1         1  Allen, Miss. Elisabeth Walton  female  29      0      0
#
#   ticket      fare cabin embarked boat body     home.dest
# 0  24160  211.3375    B5        S    2    ?  St Louis, MO

# %%
titanic["num_relatives"] = titanic["sibsp"] + titanic ["parch"]  ##will add a new column at the end

# %%
titanic.head(2)
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
#
#                          home.dest species  num_relatives
# 0                     St Louis, MO   human              0
# 1  Montreal, PQ / Chesterville, ON   human              3

# %%
houses["price_pr_sqft"] = houses["price"]/houses["sqft_living"]

# %%
houses.head(1)
# Out:
#         County          id             date  num_beds     price  bedrooms  \
# 0  King County  7129300520  20141013T000000         3  221900.0         3
#
#    bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  sqft_basement  \
# 0        1.0         1180      5650     1.0  ...        1180              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
#
#    sqft_lot15  price_pr_sqft
# 0        5650     188.050847
#
# [1 rows x 24 columns]

# %%
houses.sort_values("price_pr_sqft", ascending = False).head(1)
# Out:
#             County          id             date  num_beds     price  bedrooms  \
# 19336  King County  6021500970  20150407T000000         2  874950.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# 19336        1.0         1080      4000     1.0  ...        1080
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 19336              0      1940             0    98117  47.6902 -122.387
#
#        sqft_living15  sqft_lot15  price_pr_sqft
# 19336           1530        4240     810.138889
#
# [1 rows x 24 columns]

# %%
btc.head(1)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11

# %%
btc.set_index("Date", inplace = True)

# %%
btc["change"] = btc["Close"] - btc["Open"]

# %%
btc.sort_values("change", ascending = False).head(1)
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2021-02-08 23:59:59  2843  Bitcoin    BTC  46203.931437  38076.322807
#
#                             Open         Close        Volume     Marketcap  \
# Date
# 2021-02-08 23:59:59  38886.82729  46196.463719  1.014672e+11  8.603427e+11
#
#                           change
# Date
# 2021-02-08 23:59:59  7309.636429
