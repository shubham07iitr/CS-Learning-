# %%
import pandas as pd
houses = pd.read_csv("DataAnalysis/Data/kc_house_data.csv")
titanic = pd.read_csv("DataAnalysis/Data/titanic.csv")

# %%
netflix = pd.read_csv("DataAnalysis/Data/netflix_titles.csv", sep = "|", index_col = 0)

# %%
df =  titanic.head()

# %% [markdown]
# <h2> how to use filtering

# %%
df.sex == "female" ##will give me a boolean series
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
df[df.sex == "female"] ##will give the df
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df[df.survived == 0]
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 2   2      1      2  113781  151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781  151.55  C22 C26        S    ?  135
# 4  25      1      2  113781  151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# <even if we pass a list of booleans it will consider it a series to give a filtered df>

# %% [markdown]
# <h2> pandas is smart enough that f we pass a boolean list it will consider it a series and give back a filterd df

# %%
bools = [True,True, False, False, True]

df[bools]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic[titanic.survived == 1].head(2)
# Out:
#    pclass  survived                            name     sex     age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female      29      0
# 1       1         1  Allison, Master. Hudson Trevor    male  0.9167      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2    ?
# 1      2  113781    151.55  C22 C26        S   11    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
titanic[titanic.pclass != 1].pclass.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
houses[houses.price > 5000000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %% [markdown]
# <h2> Between method

# %%
houses[houses.bedrooms.between(5,7)].bedrooms.value_counts() ##between method is inclusive of both the values
# Out:
# bedrooms
# 5    1601
# 6     272
# 7      38
# Name: count, dtype: int64

# %% [markdown]
# <h2> isin method

# %%
countries = ["India", "Japan", "South Korea"]
netflix[netflix.country.isin(countries)].head(2) ##will give a df where all the movies from the list will be fiven back
# Out:
#    show_id     type         title    director  \
# 4       s5  TV Show  Kota Factory         NaN
# 24     s25    Movie         Jeans  S. Shankar
#
#                                                  cast country  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
#
#             date_added  release_year rating   duration  \
# 4   September 24, 2021          2021  TV-MA  2 Seasons
# 24  September 21, 2021          1998  TV-14    166 min
#
#                                             listed_in  \
# 4   International TV Shows, Romantic TV Shows, TV ...
# 24    Comedies, International Movies, Romantic Movies
#
#                                           description
# 4   In a city of coaching centers known to train I...
# 24  When the father of the man she loves insists t...

# %%
netflix[netflix.country.isin(countries)].country.value_counts()
# Out:
# country
# India          972
# Japan          245
# South Korea    199
# Name: count, dtype: int64
