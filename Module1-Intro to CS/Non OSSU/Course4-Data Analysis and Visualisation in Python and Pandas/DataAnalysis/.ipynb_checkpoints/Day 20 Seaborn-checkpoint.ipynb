# %% [markdown]
# **Seaborn is built on top of Matplot lib**
#
# - Works well with df and can plot 3-4 columns together
# - Complicated operations in a single method call

# %% [markdown]
# <h3> Load_dataset()  method </h3>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
penguin = pd.read_csv("sea

# %% [markdown]
# <h3> Seaborn Scatterplots </h3>
