# %%
log(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 log(2)
#
# NameError: name 'log' is not defined

# %%
import math

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %%
math.log2(100000**4)
# Out:
# 66.43856189774725

# %%
a = 26+26+10

# %%
a
# Out:
# 62

# %%
math.log2(62**8)
# Out:
# 47.633570483095

# %%
62**4
# Out:
# 14776336

# %%
nums1 = 100000**4
nums2 = 62**8
time1 = nums1/10000
time2 = nums2/10000
print(time1)
print(time2)
# Out:
# 1e+16
# 21834010558.4896
